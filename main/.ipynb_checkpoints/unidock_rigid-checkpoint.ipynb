# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <span style="font-size: 24px; color: #003366; font-weight: 500;">Uni-Dock Pipeline</span>
#     <img src="z_docking_files/logo.jpg" style="height: 50px; width: auto; margin-left: auto;"/>
# </div>

# %% [markdown]
# #### Import Necessary Libraries and Modules

# %%
import os
import re
import csv 
import sys
import time
import math
import torch
import random
import shutil
import psutil
import string
import logging
import subprocess
import pandas as pd
import concurrent.futures
import ipywidgets as widgets
import multiprocessing as mp

from glob import glob
from typing import Optional, List
from IPython.display import display
from rdkit import Chem, DataStructs
from z_docking_files.utils import *
from openbabel import openbabel, pybel
from multiprocessing import Pool, cpu_count
from concurrent.futures import ThreadPoolExecutor
from rdkit.Chem import AllChem, Descriptors, Draw

# %%
device = check_availability()
# Out:
# GPU availability in own5: 100.00%
# CPU availability in own5: 19.40%

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 1. Load Data </h2>
# </div>

# %%
start_time = time.time()
folder_name = "brd4_hll"
pdb_file = "brd4.pdb"  
pdbqt_file = "brd4.pdbqt"
input_csv = "input.csv"
threshold = 'dynamic'

# %%
os.makedirs(os.path.join(folder_name, "pipeline_files", "execution_time"), exist_ok=True)

# %%
input_smiles = os.path.join(folder_name, input_csv)
df = pd.read_csv(input_smiles)

df_salt = df[df['SMILES'].str.contains('\.')].copy()
print(f"\033[1m\033[34mNumber of salted compounds: \033[91m{len(df_salt)}\033[0m")
df_salt.to_csv(f'{folder_name}/salted_compounds.csv', index=False)

df_no_salt = df[~df['SMILES'].str.contains('\.')]
display(df_no_salt.head())
print(df_no_salt.shape)
# Out:
# Number of salted compounds: 6414
#             Name                               SMILES
# 0       CHEMBL98          O=C(CCCCCCC(=O)Nc1ccccc1)NO
# 1  CHEMBL4553865      CC(=O)Oc1ccc(Cn2ccnc2)c2cccnc12
# 2  CHEMBL4164698     Cc1nnn2c1-c1ccccc1N(c1ccccc1)CC2
# 3  CHEMBL4251258  Cc1noc(C)c1-c1ccc(=O)n(Cc2ccccc2)c1
# 4  CHEMBL3961812    CNc1cc(N(C)Cc2ccccc2)nn2c(C)nnc12
# (473027, 2)

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 2. SMILES to SDF </h2>
# </div>

# %%
start_time1 = time.time()

output_sdf = os.path.join(folder_name, "pipeline_files/1_sdf")
os.makedirs(os.path.join(folder_name, "pipeline_files", "1_sdf"), exist_ok=True)

convert_smiles_to_sdf_parallel(df_no_salt, output_sdf, num_conformations=10)

end_time1 = time.time()
elapsed_time_minutes = round((end_time1 - start_time1)/60, 2)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/1_smiles_to_sdf.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id
# Error processing molecule: Bad Conformer Id

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 3. SDF to Mol2 and Mol2 to PDBQT </h2>
# </div>

# %%
start_time2 = time.time()

script_path = os.path.join("z_docking_files", "1_sdf_to_pdbqt.sh")
result = subprocess.run(["/bin/bash", script_path, folder_name])
print(result.stderr)

end_time2 = time.time()
elapsed_time_minutes = round((end_time2 - start_time2)/60, 2)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/2_sdf_to_pdbqt.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# SDF to PDBQT File conversion for batch 1 completed.
# SDF to PDBQT File conversion for batch 2 completed.
# SDF to PDBQT File conversion for batch 3 completed.
# SDF to PDBQT File conversion for batch 4 completed.
# SDF to PDBQT File conversion for batch 5 completed.
# SDF to PDBQT File conversion for batch 6 completed.
# SDF to PDBQT File conversion for batch 7 completed.
# SDF to PDBQT File conversion for batch 8 completed.
# SDF to PDBQT File conversion for batch 9 completed.
# SDF to PDBQT File conversion for batch 10 completed.
# SDF to PDBQT File conversion for batch 11 completed.
# SDF to PDBQT File conversion for batch 12 completed.
# SDF to PDBQT File conversion for batch 13 completed.
# SDF to PDBQT File conversion for batch 14 completed.
# SDF to PDBQT File conversion for batch 15 completed.
# SDF to PDBQT File conversion for batch 16 completed.
# SDF to PDBQT File conversion for batch 17 completed.
# SDF to PDBQT File conversion for batch 18 completed.
# SDF to PDBQT File conversion for batch 19 completed.
# SDF to PDBQT File conversion for batch 20 completed.
# SDF to PDBQT File conversion for batch 21 completed.
# SDF to PDBQT File conversion for batch 22 completed.
# SDF to PDBQT File conversion for batch 23 completed.
# SDF to PDBQT File conversion for batch 24 completed.
# SDF to PDBQT conversion completed and files saved in folder: brd4_hll/pipeline_files/3_pdbqt
# None

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 4. PDBQT Filter  </h2>
# </div>

# %%
start_time3 = time.time()

script_path = os.path.join("z_docking_files", "2_pdbqt_to_smiles.sh")
result = subprocess.run(["/bin/bash", script_path, folder_name], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print(result.stdout)
# Out:
# PDBQT to SMILES conversion for batch 1 completed.
# PDBQT to SMILES conversion for batch 2 completed.
# PDBQT to SMILES conversion for batch 3 completed.
# PDBQT to SMILES conversion for batch 4 completed.
# PDBQT to SMILES conversion for batch 5 completed.
# PDBQT to SMILES conversion for batch 6 completed.
# PDBQT to SMILES conversion for batch 7 completed.
# PDBQT to SMILES conversion for batch 8 completed.
# PDBQT to SMILES conversion for batch 9 completed.
# PDBQT to SMILES conversion for batch 10 completed.
# PDBQT to SMILES conversion for batch 11 completed.
# PDBQT to SMILES conversion for batch 12 completed.
# PDBQT to SMILES conversion for batch 13 completed.
# PDBQT to SMILES conversion for batch 14 completed.
# PDBQT to SMILES conversion for batch 15 completed.
# PDBQT to SMILES conversion for batch 16 completed.
# PDBQT to SMILES conversion for batch 17 completed.
# PDBQT to SMILES conversion for batch 18 completed.
# PDBQT to SMILES conversion for batch 19 completed.
# PDBQT to SMILES conversion for batch 20 completed.
# PDBQT to SMILES conversion for batch 21 completed.
# PDBQT to SMILES conversion for batch 22 completed.
# PDBQT to SMILES conversion for batch 23 completed.
# PDBQT to SMILES conversion for batch 24 completed.
# PDBQT to SMILES conversion completed and files saved in folder: brd4_hll/pipeline_files/4_smiles

# %%
check_pdbqt_files(folder_name, input_smiles)
copy_correct_pdbqt_files(folder_name, input_smiles)

end_time3 = time.time()
elapsed_time_minutes = round((end_time3 - start_time3)/60, 2)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/3_pdbqt_filter_using_tanimoto.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# [01:22:53] Explicit valence for atom # 29 C, 5, is greater than permitted
# [01:22:53] Explicit valence for atom # 29 C, 5, is greater than permitted
# [01:22:54] Explicit valence for atom # 21 C, 5, is greater than permitted
# [01:22:54] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 C, 5, is greater than permitted
# [01:22:55] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:56] Explicit valence for atom # 2 N, 4, is greater than permitted
# [01:22:56] Explicit valence for atom # 4 N, 4, is greater than permitted
# [01:22
Explicit valence for atom # 10 C, 5, is greater than permitted
# [01:27:34] Explicit valence for atom # 18 N, 4, is greater than permitted
# [01:27:34] Explicit valence for atom # 10 C, 5, is greater than permitted
# [01:27:35] Explicit valence for atom # 16 N, 4, is greater than permitted
# [01:27:35] Explicit valence for atom # 7 C, 5, is greater than permitted
# [01:27:35] Explicit valence for atom # 0 C, 5, is greater than permitted
# [01:27:36] Explicit valence for atom # 11 C, 5, is greater than permitted
# [01:27:36] Explicit valence for atom # 20 C, 5, is greater than permitted
# [01:27:37] Explicit valence for atom # 0 C, 5, is greater than permitted
# [01:27:37] Explicit valence for atom # 8 C, 5, is greater than permitted
# [01:27:37] Explicit valence for atom # 0 C, 5, is greater than permitted
# Compounds filtered out using Dice Similarity: 49283

# %% [markdown]
# <div style="background-color:#8E44AD; color:#ECF0F1; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 5. Uni-Dock Docking </h2>
# </div>

# %%
start_time4 = time.time()

protein = os.path.join(folder_name, pdbqt_file)
num_batches = create_ligands_path_batchwise(folder_name)
ligand_batches = [f"unidock_pdbqt_batch_{i+1}.txt" for i in range(num_batches)]  
output_result_base = os.path.join(folder_name, "pipeline_files/6_pdbqt_out")
os.makedirs(output_result_base, exist_ok=True)

for i, ligands_batch_file in enumerate(ligand_batches):
    protein = os.path.join(folder_name, pdbqt_file)
    ligands_path = os.path.join(folder_name, "pipeline_files", ligands_batch_file)
    output_result_pdbqt = output_result_base
    batch_output_logs = os.path.join(folder_name, f"pipeline_files/unidock_output_batch_{i+1}.txt")
    open(batch_output_logs, 'w').close()
    with open(ligands_path, "r") as batch_file:
        ligands = batch_file.read().strip()

    unidock_command = (
        f"unidock "
        f"--receptor {protein} "
        f"--gpu_batch $(cat {ligands_path}) "
        f"--search_mode detail "
        f"--scoring vina "
        f"--center_x 86.79 "
        f"--center_y 43.89 "
        f"--center_z 65.43 "
        f"--size_x 20.00 "
        f"--size_y 20.00 "
        f"--size_z 20.00 "
        f"--num_modes 10 "
        f"--dir {output_result_pdbqt} "
        f">> {batch_output_logs} 2>&1"
    )

    os.system(unidock_command)
    print(f"Docking Process completed for Batch_{i+1}")

print("\033[1m\033[34mDocking Process completed for all Batches and files saved in folder: \033[91m{}\033[0m".format(output_result_pdbqt))

end_time4 = time.time()
elapsed_time_minutes = round((end_time4 - start_time4)/60, 2)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/4_docking.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# Docking Process completed for Batch_1
# Docking Process completed for Batch_2
# Docking Process completed for Batch_3
# Docking Process completed for Batch_4
# Docking Process completed for Batch_5
# Docking Process completed for Batch_6
# Docking Process completed for Batch_7
# Docking Process completed for Batch_8
# Docking Process completed for Batch_9
# Docking Process completed for Batch_10
# Docking Process completed for Batch_11
# Docking Process completed for Batch_12
# Docking Process completed for Batch_13
# Docking Process completed for Batch_14
# Docking Process completed for Batch_15
# Docking Process completed for Batch_16
# Docking Process completed for Batch_17
# Docking Process completed for Batch_18
# Docking Process completed for Batch_19
# Docking Process completed for Batch_20
# Docking Process completed for Batch_21
# Docking Process completed for Batch_22
# Docking Process completed for all Batches and files saved in folder: brd4_hll/pipeline_files/6_pdbqt_out

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 6. Extract Affinity values </h2>
# </div>

# %%
affinity_from_pdbqt_files(folder_name)
# Out:
# Affnity values extracted and saved in folder: brd4_hll/pipeline_files/2_extract_affinity_from_pdbqt.csv

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 7. Extract Compounds based on Affinity threshold </h2>
# </div>

# %%
extraction_based_on_threshold(folder_name, threshold)
extract_model1(folder_name)
# Out:
# Compounds Extracted based on threshold value
# Extracted Model_1 content and saved in folder: brd4_hll/pipeline_files/8_pdbqt_out_threshold_m1

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 8. PDBQT to Mol2 and Mol2 to SDF</h2>
# </div>

# %%
start_time5 = time.time()

script_path = os.path.join("z_docking_files", "3_pdbqt_to_sdf.sh")
result = subprocess.run(["/bin/bash", script_path, folder_name])
print(result.stderr)


end_time5 = time.time()
elapsed_time_minutes = round((end_time5 - start_time5)/60, 2)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/5_pdbqt_to_sdf.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# PDBQT to SDF conversion for batch 1 is completed.
# PDBQT to SDF conversion for batch 2 is completed.
# PDBQT to SDF conversion for batch 3 is completed.
# PDBQT to SDF conversion for batch 4 is completed.
# PDBQT to SDF conversion completed and files saved in folder: brd4_hll/pipeline_files/9_sdf_out
# None

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 1px; border-radius: 10px;">
#     <h2 style="font-size: 16px; margin-left: 10px;"> Step 9. PoseBusters Filter </h2>
# </div>

# %%
start_time6 = time.time()

script_path = os.path.join("z_docking_files", "4_posebusters_filter.sh")
result = subprocess.run(["/bin/bash", script_path, folder_name, pdb_file])
print(result.stdout)

end_time6 = time.time()
elapsed_time_minutes = round((end_time6 - start_time6)/60, 4)
file_path = os.path.join(folder_name, "pipeline_files/execution_time/6_posebusters_filter.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
# Out:
# Check PoseBusters Progress... brd4_hll/pipeline_files/posebusters_output.txt

# %%
process_posebusters(folder_name, input_smiles)
# Out:
# PoseBusters filteration completed and file saved in folder: brd4_hll/pipeline_files/5_posebusters_output.csv
# Compounds filtered out by PoseBusters: 23063

# %%
end_time = time.time()
elapsed_time_minutes = round((end_time - start_time)/60, 1)

file_path = os.path.join(folder_name, "pipeline_files/execution_time/total_execution_time.txt")
with open(file_path, "w") as file:
    file.write(f"{elapsed_time_minutes} minutes")
print(f"\033[1m\033[34mTotal execution time (minutes): \033[91m{elapsed_time_minutes}\033[0m")
# Out:
# Total execution time (minutes): 1816.1

# %% [markdown]
# .

# %% [markdown]
# <div style="background-color:#4B6587; color:#F0E5CF; padding: 3px; border-radius: 10px;">
# </div>

# %% [markdown]
# #### Check SDF File

# %%
# sdf_file_path = os.path.join(folder_name, "pipeline_files/ligands_sdf/CHEMBL1958347.sdf")
# process_sdf_file(sdf_file_path)

# %% [markdown]
# #### Check PDBQT File

# %%
# file_path = os.path.join(folder_name, "pipeline_files/ligands_pdbqt_out/BB_44_out.pdbqt")
# print(''.join(open(file_path, 'r').readlines()))

# %% [markdown]
# #### Check Molecule Structure File

# %%
# mol = Chem.MolFromSmiles('C[C@@H]1CNC(=O)C2(CNC2)C/C=C/CN(C)S(=O)(=O)c2cccc(c2)C(=O)N1.OC(=O)C(F)(F)F')
# img = Draw.MolToImage(mol, size=(600, 600))
# display(img)

# %%
# df11 = pd.read_csv('minD_antibact_obabel/output.csv')
# df11.head()

# %%
# df12 = df11[df11['SMILES'].str.startswith('Cl.')]
# df12.head()
